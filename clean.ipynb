# %% [markdown]
# # Step one: Cleaning
#
# In this notebook we will focus on taking the original data file and reducing all the errors in it. This will produce a clean file that will allow for meaningful analysis.
#
# ## Importing libraries and reading the file

# %%
import pandas as pd

attacks = pd.read_csv("data/attacks.csv", encoding='unicode_escape')

#We will alos run the 'cleaning.py' script as it will define functions we will use

# %run -i 'src/cleaning.py'

# %% [markdown]
# ## Initial exploration
# Now we will start exploring the file. Using the ".head()" we can get a preview of the columns and a the first rows of the dataset.

# %%
attacks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                                                      href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.25-Wolfe.pdf
# 1    http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.18-McNeely.pdf
# 2     http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.09-Denges.pdf
# 3  http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.08-Arrawarra.pdf
# 4      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.04-Ramos.pdf
#
#                                                                              href  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.25-Wolfe.pdf
# 1    http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.18-McNeely.pdf
# 2     http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.09-Denges.pdf
# 3  http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.08-Arrawarra.pdf
# 4      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.04-Ramos.pdf
#
#   Case Number.1 Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25    2018.06.25         6303.0         NaN         NaN
# 1    2018.06.18    2018.06.18         6302.0         NaN         NaN
# 2    2018.06.09    2018.06.09         6301.0         NaN         NaN
# 3    2018.06.08    2018.06.08         6300.0         NaN         NaN
# 4    2018.06.04    2018.06.04         6299.0         NaN         NaN
#
# [5 rows x 24 columns]

# %%
attacks.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
attacks.shape
# Out:
# (25723, 24)

# %% [markdown]
# Using 'head()' , '.columns' and '.shape' we can see that we are dealing with a file of 24 columns (names listed above) and 25723 entries. Lets explore further:

# %%
attacks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB

# %% [markdown]
# From this output we gather a few things:
#
# #### Types and names of the columns:
# * There is only two columns with floats
#     * This is odd considering that the column "Age" should also be a number
#     * The column "Original order" probably adds little to no value
# * Columns 0, 19 and 20 all reference a case number
# * Columns 17 and 18 could also be duplicated, since they both reference "href"
#
# ####  Non-null values:
# * Column 0 "Case number" has significantly more non-null values than the rest of the columns
# * Columns 22 and 23 are unnamed and have 2 or less non-null values, these columns add no value to the analysis
# * Several columns have a non-null count nearing 6300. But most columns have less than this ammount. This means that we are dealing with a great amount of incomplete rows.

# %% [markdown]
# ### Deleting Unnamed columns:
# We will start cleaning the file by deleting the last 2 columns. For this we will use a function declared in the 'cleaning.py' ran in the beginning of this notebook:

# %%
delete_columns(attacks,['Unnamed: 22','Unnamed: 23'])
# Out:
# Deleted columns:  ['Unnamed: 22', 'Unnamed: 23']

# %%
attacks.sample(5)
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 6330            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 14975         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 7481            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 17458         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 24022         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Fatal (Y/N) Time Species  Investigator or Source  pdf href formula  \
# 6330   ...         NaN  NaN      NaN                    NaN  NaN          NaN
# 14975  ...         NaN  NaN      NaN                    NaN  NaN          NaN
# 7481   ...         NaN  NaN      NaN                    NaN  NaN          NaN
# 17458  ...         NaN  NaN      NaN                    NaN  NaN          NaN
# 24022  ...         NaN  NaN      NaN                    NaN  NaN          NaN
#
#       href Case Number.1 Case Number.2 original order
# 6330   NaN           NaN           NaN            NaN
# 14975  NaN           NaN           NaN            NaN
# 7481   NaN           NaN           NaN            NaN
# 17458  NaN           NaN           NaN            NaN
# 24022  NaN           NaN           NaN            NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Dealing with the "Case Number" columns
# Our data set contains 3 columns referring to a case number. For this we will use a function declared in the 'cleaning.py' ran in the beginning of this notebook:

# %%
compare_columns(attacks,["Case Number","Case Number.1","Case Number.2"])
# Out:
# Column information:
# Columns            Case Number  Case Number.1  Case Number.2
# Lengths                  25723          25723          25723
# Non - null values         8702           6302           6302
# Data type comparison:
#                  Case Number  Case Number.1  Case Number.2
# <class 'float'>        17021          19421          19421
# <class 'str'>           8702           6302           6302
# Value comparisons:
#                Case Number  Case Number.1  Case Number.2
# Case Number          25723          23298          23318
# Case Number.1        23298          25723          25703
# Case Number.2        23318          25703          25723
# The above matrix shows the amount of rows that each column shares with other columns. E.g. how many cells store the same information in both columns
# Sample of columns with differences:
#         Case Number Case Number.1 Case Number.2
# 19516           NaN           NaN           NaN
# 82     2017.09.16.b  2017.09.16.b  2017.09.16.b
# 9900            NaN           NaN           NaN
# 24839           NaN           NaN           NaN
# 3042     1981.02.02    1981.02.02    1981.02.02

# %% [markdown]
# We can see that the columns "Case Number.1" and "Case Number.2" hold almost the same information (They return the same values in all the tests, and in the comparison matrix they only have 20 values that are different). Lets check these values:

# %%
different_value_columns(attacks, ["Case Number.1", "Case Number.2"])
# Out:
# Columns differ in the following 20 values
#      Case Number.1 Case Number.2
# 34      2018.04.02    2018.04.03
# 117   2017/07.20.a  2017.07.20.a
# 144     2017.06.06    2017.05.06
# 217     2016.09.16    2016.09.15
# 314   2015.01.24.b  2016.01.24.b
# 334     2015.11.07    2015.12.23
# 339     2015.10.28  2015.10.28.a
# 560     2013.05.04    2014.05.04
# 3522    1967/07.05    1967.07.05
# 3795  1962.08.30.b  1962,08.30.b
# 3880  1961.09,06.R  1961.09.02.R
# 4403    1952.08.04    1952.08.05
# 4425  1951.12.15.R  1851.12.15.R
# 5275  1919.00.00.R  1900.00.00.R
# 5358  1913.17.10.R  1913.07.10.R
# 5386  1911.07.31.T  1911.07.31.R
# 5777  1884.04.28.R  1884.04.38.R
# 5883  1874.06.18.R  1876.06.18.R
# 6009    1853.04.29    1853,94.29
# 6122  1808.05.01.R  1808.06.01.R

# %% [markdown]
# We can see that the columns hold mostly the same information. Most of the differences are symbols (commas for periods or slashes) and missing letters. We will keep column Case Number.2 and drop Case Number.1

# %%
attacks.drop(["Case Number.1"], axis=1, inplace=True)
attacks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#                                                       Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and paddle damaged           N
# 1                                 Minor injury to left thigh           N
# 2               Injury to left lower leg from surfboard skeg           N
# 3                                  Minor injury to lower leg           N
# 4          Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time         Species           Investigator or Source  \
# 0          18h00      White shark                R. Collier, GSAF
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2          07h45              NaN  K.McMurray, TrackingSharks.com
# 3            NaN        2 m shark                  B. Myatt, GSAF
# 4            NaN  Tiger shark, 3m                       A .Kipper
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                                                      href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.25-Wolfe.pdf
# 1    http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.18-McNeely.pdf
# 2     http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.09-Denges.pdf
# 3  http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.08-Arrawarra.pdf
# 4      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.04-Ramos.pdf
#
#                                                                              href  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.25-Wolfe.pdf
# 1    http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.18-McNeely.pdf
# 2     http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.09-Denges.pdf
# 3  http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.08-Arrawarra.pdf
# 4      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.04-Ramos.pdf
#
#   Case Number.2 original order
# 0    2018.06.25         6303.0
# 1    2018.06.18         6302.0
# 2    2018.06.09         6301.0
# 3    2018.06.08         6300.0
# 4    2018.06.04         6299.0
#
# [5 rows x 21 columns]

# %% [markdown]
# Now lets compare "Case Number" with "Case Number.2"

# %%
different_value_columns(attacks, ["Case Number.2", "Case Number"])
# Out:
# Columns differ in the following 2405 values
#       Case Number.2   Case Number
# 390      2015.07.10    2015.07-10
# 4949   1934.02.08.R  1934.01.08.R
# 5488   1905.09.06.R
# 5944     1864.05.00       1864.05
# 6302                            0
# ...             ...           ...
# 8698                            0
# 8699                            0
# 8700                            0
# 8701                            0
# 25722                          xx
#
# [2405 rows x 2 columns]

# %% [markdown]
# We can see that "Case Number" has a great deal of 0 values, lets print the value_counts for "Case Number" where it is different from "Case Number.2"

# %%
print_test = different_value_columns(attacks, ["Case Number.2", "Case Number"])
print_test["Case Number"].value_counts()
# Out:
# Columns differ in the following 2405 values
# 0               2400
# 2015.07-10         1
# 1934.01.08.R       1
#                    1
# 1864.05            1
# xx                 1
# Name: Case Number, dtype: int64

# %% [markdown]
# As we suspected, "Case Number" has 2400 values where it holds "0", one "xx" value and only 4 cases where it is similar to "Case Number.2". Since "Case Number.2" holds more complete information in these values and "Case Number" adds no value with these 0 values, we will drop it.

# %%
attacks.drop(["Case Number"], axis=1, inplace=True)
attacks.head()
# Out:
#           Date    Year        Type    Country             Area  \
# 0  25-Jun-2018  2018.0     Boating        USA       California
# 1  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                                       Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and paddle damaged           N
# 1                                 Minor injury to left thigh           N
# 2               Injury to left lower leg from surfboard skeg           N
# 3                                  Minor injury to lower leg           N
# 4          Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time         Species           Investigator or Source  \
# 0          18h00      White shark                R. Collier, GSAF
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2          07h45              NaN  K.McMurray, TrackingSharks.com
# 3            NaN        2 m shark                  B. Myatt, GSAF
# 4            NaN  Tiger shark, 3m                       A .Kipper
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                                                      href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.25-Wolfe.pdf
# 1    http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.18-McNeely.pdf
# 2     http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.09-Denges.pdf
# 3  http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.08-Arrawarra.pdf
# 4      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.04-Ramos.pdf
#
#                                                                              href  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.25-Wolfe.pdf
# 1    http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.18-McNeely.pdf
# 2     http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.09-Denges.pdf
# 3  http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.08-Arrawarra.pdf
# 4      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.04-Ramos.pdf
#
#   Case Number.2  original order
# 0    2018.06.25          6303.0
# 1    2018.06.18          6302.0
# 2    2018.06.09          6301.0
# 3    2018.06.08          6300.0
# 4    2018.06.04          6299.0

# %% [markdown]
# Now lets explore the columsn "href formula" and "href" since they appear to hold the same information. Since they hold web addresses, I'll set the column width to be greater in order to be able to see the full information.

# %%
pd.set_option("max_colwidth", 500)
different_value_columns(attacks, ["href formula", "href"])
# Out:
# Columns differ in the following 60 values
#                                                                                         href formula  \
# 50                      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.01.13-Stewart.pdf
# 96                     http://sharkattackfile.net/spreadsheets/pdf_directory/2017.08.27-Brundler.pdf
# 131             http://sharkattackfile.net/spreadsheets/pdf_directory/2017.06.05-FrenchPolynesia.pdf
# 133                        http://sharkattackfile.net/spreadsheets/pdf_directory/2017.06.11-Goff.pdf
# 141                     http://sharkattackfile.net/spreadsheets/pdf_directory/2017.05.27-Selwood.pdf
# 168                   http://sharkattackfile.net/spreadsheets/pdf_directory/2017.03.19-Fernandez.pdf
# 234                       http://sharkattackfile.net/spreadsheets/pdf_directory/2016.07.29-Spain.pdf
# 241                  http://sharkattackfile.net/spreadsheets/pdf_directory/2016.07.23.a-Cutbirth.pdf
# 276                      http://sharkattackfile.net/spreadsheets/pdf_directory/2016.05.21.a-Girl.pdf
# 324                    http://sharkattackfile.net/spreadsheets/pdf_directory/2015.12.21.a-Brazil.pdf
# 332                  http://sharkattackfile.net/spreadsheets/pdf_directory/2015.11.15.a-Engelman.pdf
# 352                 http://sharkattackfile.net/spreadsheets/pdf_directory/2015.10.05.a-Slaughter.pdf
# 401                 http://sharkattackfile.net/spreadsheets/pdf_directory/2015.06.27.a-Swanepoel.pdf
# 453                      http://sharkattackfile.net/spreadsheets/pdf_directory/2015.01.24-Murray.pdf
# 484                        http://sharkattackfile.net/spreadsheets/pdf_directory/2014.10.19-Tara.pdf
# 485                    http://sharkattackfile.net/spreadsheets/pdf_directory/2014.10.18-Roberson.pdf
# 486                     http://sharkattackfile.net/spreadsheets/pdf_directory/2014.10.17-Olsson, pdf
# 493                   http://sharkattackfile.net/spreadsheets/pdf_directory/2014.10.03.b-Kayaks2.pdf
# 494                   http://sharkattackfile.net/spreadsheets/pdf_directory/2014.10.03.a-Kayaks1.pdf
# 515                       http://sharkattackfile.net/spreadsheets/pdf_directory/2014.08.15-Hayes.pdf
# 527                       http://sharkattackfile.net/spreadsheets/pdf_directory/2014.07.22-Rintz.pdf
# 545                     http://sharkattackfile.net/spreadsheets/pdf_directory/2014.06.09.a-Berry.pdf
# 569                   http://sharkattackfile.net/spreadsheets/pdf_directory/2014.04.03-Armstrong.pdf
# 583                    http://sharkattackfile.net/spreadsheets/pdf_directory/2014.02.07.b-Torres.pdf
# 584                 http://sharkattackfile.net/spreadsheets/pdf_directory/2014.02.07-PorpoiseBay.pdf
# 585                     http://sharkattackfile.net/spreadsheets/pdf_directory/2014.01.26-O'Connor.pf
# 586                           http://sharkattackfile.net/spreadsheets/pdf_directory/2014.01.25-Grant
# 587                      http://sharkattackfile.net/spreadsheets/pdf_directory/2014.01.04-Rianto.pdf
# 588           http://sharkattackfile.net/spreadsheets/pdf_directory/2014.00.00.b-OceanicWhitetip.pdf
# 590                http://sharkattackfile.net/spreadsheets/pdf_directory/2013.12.25-NewCaledonia.pdf
# 600                    http://sharkattackfile.net/spreadsheets/pdf_directory/2013.11.22-Gardiner.pdf
# 601                        http://sharkattackfile.net/spreadsheets/pdf_directory/2013.11.12-Daly.pdf
# 602                     http://sharkattackfile.net/spreadsheets/pdf_directory/2013.11.10-Bahamas.pdf
# 603                     http://sharkattackfile.net/spreadsheets/pdf_directory/2013.11.07.b-Gates.pdf
# 604                    http://sharkattackfile.net/spreadsheets/pdf_directory/2013.11.07.a-Melian.pdf
# 605            http://sharkattackfile.net/spreadsheets/pdf_directory/2013.10.31-ChristianBrandon.pdf
# 606                     http://sharkattackfile.net/spreadsheets/pdf_directory/2013.10.28-Simmons.pdf
# 607                    http://sharkattackfile.net/spreadsheets/pdf_directory/2013.10.26.b-Tanguy.pdf
# 671                                                               pdf-directory/2013.05.27.b-Ena.pdf
# 672               http://sharkattackfile.net/spreadsheets/pdf_directory/2013.05.27.a-Kirkpatrick.pdf
# 1046                                     http://sharkattackfile.net/spreadsheets/pdf_directory/12.26
# 1441                     http://sharkattackfile.net/spreadsheets/pdf_directory/2006.08.22.b-Melo.pdf
# 1442                     http://sharkattackfile.net/spreadsheets/pdf_directory/2006.08.22.a-Coba.pdf
# 2702  http://sharkattackfile.net/spreadsheets/pdf_directory/1989.00.00.a-Virginia-spearfisherman.pdf
# 3244
# 3245                                                                                         #VALUE!
# 3775               http://sharkattackfile.net/spreadsheets/pdf_directory/1963.00.00.a-Seychelles.pdf
# 3829                   http://sharkattackfile.net/spreadsheets/pdf_directory/1962.03.25.b-Luxton.pdf
# 4143                http://sharkattackfile.net/spreadsheets/pdf_directory/1958.08.31-NV-Ensenada.pdf
# 4154                 http://sharkattackfile.net/spreadsheets/pdf_directory/1958.07.00.b-Waterman.pdf
# 4621           http://sharkattackfile.net/spreadsheets/pdf_directory/1945.07.30-USS Indianapolis.pdf
# 4872               http://sharkattackfile.net/spreadsheets/pdf_directory/1936.08.04.R-PearlDiver.pdf
# 4898                http://sharkattackfile.net/spreadsheets/pdf_directory/1935.08.24-Atherfield.pdf
# 4949                   http://sharkattackfile.net/spreadsheets/pdf_directory/1924.02.08.R-Turkey.pdf
# 5245                      http://sharkattackfile.net/spreadsheets/pdf_directory/1921.07.21-Ellis.pdf
# 5349                 http://sharkattackfile.net/spreadsheets/pdf_directory/1913.12.26.R-Schwertz.pdf
# 5556                    http://sharkattackfile.net/spreadsheets/pdf_directory/1900.09.05-Hartman.pdf
# 5701                    http://sharkattackfile.net/spreadsheets/pdf_directory/1890.06.26-Mayonni.pdf
# 6110                    http://sharkattackfile.net/spreadsheets/pdf_directory/1819.07.08.R-Cadiz.pdf
# 6166                 http://sharkattackfile.net/spreadsheets/pdf_directory/1637.00.00.R-Manrique.pdf
#
#                                                                                                                                               href
# 50              http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2018.01.13-Stewart.pdf
# 96             http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2017.08.27-Brundler.pdf
# 131     http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2017.06.05-FrenchPolynesia.pdf
# 133                http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2017.06.11-Goff.pdf
# 141             http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2017.05.27-Selwood.pdf
# 168           http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2017.03.19-Fernandez.pdf
# 234               http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2016.07.29-Spain.pdf
# 241                                                                  http://sharkattackfile.net/spreadsheets/pdf_directory/2016.07.23-Cutbirth.pdf
# 276              http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2016.05.21.a-Girl.pdf
# 324            http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2015.12.21.a-Brazil.pdf
# 332          http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2015.11.15.a-Engelman.pdf
# 352                                                                 http://sharkattackfile.net/spreadsheets/pdf_directory/2015.10.05-Slaughter.pdf
# 401                                                                 http://sharkattackfile.net/spreadsheets/pdf_directory/2015.06.27-Swanepoel.pdf
# 453              http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2015.01.24-Murray.pdf
# 484                http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2014.10.19-Tara.pdf
# 485                                                                      http://sharkattackfile.net/spreadsheets/pdf_directory/2014.10.18-Roberson
# 486                                                                     http://sharkattackfile.net/spreadsheets/pdf_directory/2014.10.14-Bandy.pdf
# 493                                                              http://sharkattackfile.net/spreadsheets/pdf_directory/2014.10.02.b-Vandenberg.pdf
# 494                                                              http://sharkattackfile.net/spreadsheets/pdf_directory/2014.10.02.b-Vandenberg.pdf
# 515                                                                     http://sharkattackfile.net/spreadsheets/pdf_directory/2014.08.12-Hayes.pdf
# 527               http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2014.07.22-Rintz.pdf
# 545                                                                     http://sharkattackfile.net/spreadsheets/pdf_directory/2014.06.09-Berry.pdf
# 569           http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2014.04.03-Armstrong.pdf
# 583                                                                     http://sharkattackfile.net/spreadsheets/pdf_directory/w014.01.25-Grant.pdf
# 584                                                                     http://sharkattackfile.net/spreadsheets/pdf_directory/w014.01.25-Grant.pdf
# 585                                                                     http://sharkattackfile.net/spreadsheets/pdf_directory/w014.01.25-Grant.pdf
# 586                                                                     http://sharkattackfile.net/spreadsheets/pdf_directory/w014.01.25-Grant.pdf
# 587                                                                                                             pdf_directory2014.01.04-Riano.pdf
# 588   http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2014.00.00.b-OceanicWhitetip.pdf
# 590                                                             http://sharkattackfile.net/spreadsheets/pdf_directory/2013.12.25-NewCaledonia.pdf
# 600                                                                      http://sharkattackfile.net/spreadsheets/pdf_directory/2013.11.22-Gardiner
# 601                                                                          http://sharkattackfile.net/spreadsheets/pdf_directory/2013.11.12-Daly
# 602                                                                       http://sharkattackfile.net/spreadsheets/pdf_directory/2013.11.10-Bahamas
# 603                                                                       http://sharkattackfile.net/spreadsheets/pdf_directory/2013.11.07.b-Gates
# 604                                                                      http://sharkattackfile.net/spreadsheets/pdf_directory/2013.11.07.a-Melian
# 605                                                              http://sharkattackfile.net/spreadsheets/pdf_directory/2013.10.31-ChristianBrandon
# 606                                                                       http://sharkattackfile.net/spreadsheets/pdf_directory/2013.10.28-Simmons
# 607                                                                      http://sharkattackfile.net/spreadsheets/pdf_directory/2013.10.26.b-Tanguy
# 671                                                                     http://sharkattackfile.net/spreadsheets/pdf_directory/2013.05.27.b-Ena.pdf
# 672                                                               http://sharkattackfile.net/spreadsheets/pdf_directory/2013.05.27-Kirkpatrick.pdf
# 1046                                                                     http://sharkattackfile.net/spreadsheets/pdf_directory/2010.02.01-Ward.pdf
# 1441                                                                http://sharkattackfile.net/spreadsheets/pdf_directory/2006.08.22-IsaulCoba.pdf
# 1442                                                      http://sharkattackfile.net/spreadsheets/pdf_directory/2006.08.22.b-Brazil-incomplete.pdf
# 2702                                                  http://sharkattackfile.net/spreadsheets/pdf_directory/1989.00.00-Virginia-spearfisherman.pdf
# 3244                                                                http://sharkattackfile.net/spreadsheets/pdf_directory/1975.01.19-Barrowman.pdf
# 3245                                                              http://sharkattackfile.net/spreadsheets/pdf_directory/1975.00.00.b-Toussaint.pdf
# 3775       http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/1963.00.00.a-Seychelles.pdf
# 3829           http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/1962.03.25.b-Luxton.pdf
# 4143                                                            http://sharkattackfile.net/spreadsheets/pdf_directory/1958.08.31.a-NV-Ensenada.pdf
# 4154                                                             http://sharkattackfile.net/spreadsheets/pdf_directory/1958.07.00.b - Waterman.pdf
# 4621                                                       http://sharkattackfile.net/spreadsheets/pdf_directory/1945.07.30 - USS Indianapolis.pdf
# 4872       http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/1936.08.04.R-PearlDiver.pdf
# 4898                                                                   http://sharkattackfile.net/spreadsheets/pdf_directory/1935.08.24-Atherfield
# 4949           http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/1924.02.08.R-Turkey.pdf
# 5245              http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/1921.07.21-Ellis.pdf
# 5349         http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/1913.12.26.R-Schwertz.pdf
# 5556            http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/1900.09.05-Hartman.pdf
# 5701            http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/1890.06.26-Mayonni.pdf
# 6110                                                                    http://sharkattackfile.net/spreadsheets/pdf_directory/1819.07.08-Cadiz.pdf
# 6166                                                                 http://sharkattackfile.net/spreadsheets/pdf_directory/1637.00.00-Manrique.pdf

# %% [markdown]
# We can see that most of the differences are due to differences in the case number. We can also see that href have several instances where it repeats the web address. Since this column adds little value to the analysis we will conduct later, for simplicity I will fill the missing values of "href formula" with the values in "href" and drop the "href" column.

# %%
attacks.iloc[3245,16] = attacks.iloc[3245,17]
attacks.iloc[3244,16] = attacks.iloc[3244,17]
attacks.drop(["href"], axis=1, inplace=True)
attacks.head()
# Out:
#           Date    Year        Type    Country             Area  \
# 0  25-Jun-2018  2018.0     Boating        USA       California
# 1  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                                       Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and paddle damaged           N
# 1                                 Minor injury to left thigh           N
# 2               Injury to left lower leg from surfboard skeg           N
# 3                                  Minor injury to lower leg           N
# 4          Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time         Species           Investigator or Source  \
# 0          18h00      White shark                R. Collier, GSAF
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2          07h45              NaN  K.McMurray, TrackingSharks.com
# 3            NaN        2 m shark                  B. Myatt, GSAF
# 4            NaN  Tiger shark, 3m                       A .Kipper
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                                                      href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.25-Wolfe.pdf
# 1    http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.18-McNeely.pdf
# 2     http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.09-Denges.pdf
# 3  http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.08-Arrawarra.pdf
# 4      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.04-Ramos.pdf
#
#   Case Number.2  original order
# 0    2018.06.25          6303.0
# 1    2018.06.18          6302.0
# 2    2018.06.09          6301.0
# 3    2018.06.08          6300.0
# 4    2018.06.04          6299.0

# %% [markdown]
# Now that we have altered our data frame a bit, lets tidy up. Ill reorder and rename a few columns to maintain structre and then we will check the shape and non-null count again.

# %%
attacks = attacks[['Case Number.2', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity',
       'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species ',
       'Investigator or Source', 'pdf', 'href formula',
       'original order']]
attacks.rename(columns={'href formula' : 'href',
                        'Case Number.2' : 'Case Number',
                        'Species ' : 'Species'}, inplace=True, errors='raise')
attacks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                                       Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and paddle damaged           N
# 1                                 Minor injury to left thigh           N
# 2               Injury to left lower leg from surfboard skeg           N
# 3                                  Minor injury to lower leg           N
# 4          Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time          Species          Investigator or Source  \
# 0          18h00      White shark                R. Collier, GSAF
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2          07h45              NaN  K.McMurray, TrackingSharks.com
# 3            NaN        2 m shark                  B. Myatt, GSAF
# 4            NaN  Tiger shark, 3m                       A .Kipper
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                                                              href  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.25-Wolfe.pdf
# 1    http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.18-McNeely.pdf
# 2     http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.09-Denges.pdf
# 3  http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.08-Arrawarra.pdf
# 4      http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.04-Ramos.pdf
#
#    original order
# 0          6303.0
# 1          6302.0
# 2          6301.0
# 3          6300.0
# 4          6299.0

# %%
attacks.tail(100)
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 25623         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25624         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25625         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25626         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25627         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# ...           ...  ...   ...  ...     ...  ...      ...      ...  ...  ...
# 25718         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25719         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25720         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25721         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        Age Injury Fatal (Y/N) Time Species Investigator or Source  pdf href  \
# 25623  NaN    NaN         NaN  NaN     NaN                    NaN  NaN  NaN
# 25624  NaN    NaN         NaN  NaN     NaN                    NaN  NaN  NaN
# 25625  NaN    NaN         NaN  NaN     NaN                    NaN  NaN  NaN
# 25626  NaN    NaN         NaN  NaN     NaN                    NaN  NaN  NaN
# 25627  NaN    NaN         NaN  NaN     NaN                    NaN  NaN  NaN
# ...    ...    ...         ...  ...     ...                    ...  ...  ...
# 25718  NaN    NaN         NaN  NaN     NaN                    NaN  NaN  NaN
# 25719  NaN    NaN         NaN  NaN     NaN                    NaN  NaN  NaN
# 25720  NaN    NaN         NaN  NaN     NaN                    NaN  NaN  NaN
# 25721  NaN    NaN         NaN  NaN     NaN                    NaN  NaN  NaN
# 25722  NaN    NaN         NaN  NaN     NaN                    NaN  NaN  NaN
#
#        original order
# 25623             NaN
# 25624             NaN
# 25625             NaN
# 25626             NaN
# 25627             NaN
# ...               ...
# 25718             NaN
# 25719             NaN
# 25720             NaN
# 25721             NaN
# 25722             NaN
#
# [100 rows x 19 columns]

# %% [markdown]
# It looks like the bottom of our dataframe is full of NaNs. Lets get rid of all the rows that are just NaNs.

# %%
attacks.dropna(how='all',inplace=True)
attacks.tail(100)
# Out:
#      Case Number                 Date  Year        Type       Country  \
# 6209     ND.0110  No date, late 1960s   0.0  Unprovoked     VENEZUELA
# 6210     ND-0109          Before 2006   0.0  Unprovoked           USA
# 6211     ND-0108          Before 2003   0.0  Unprovoked        GREECE
# 6212     ND-0107          Before 2004   0.0        Boat    MOZAMBIQUE
# 6213     ND-0106          Before 1962   0.0  Unprovoked  SOUTH AFRICA
# ...          ...                  ...   ...         ...           ...
# 6304         NaN                  NaN   NaN         NaN           NaN
# 6305         NaN                  NaN   NaN         NaN           NaN
# 6306         NaN                  NaN   NaN         NaN           NaN
# 6307         NaN                  NaN   NaN         NaN           NaN
# 6308         NaN                  NaN   NaN         NaN           NaN
#
#                        Area                        Location  \
# 6209    Los Roques  Islands                             NaN
# 6210                Florida  Tampa Bay, Hillsborough County
# 6211     Dodecanese Islands                Near Symi Island
# 6212     Inhambane Province                   Off Inhambane
# 6213  Western Cape Province       Murray Bay, Robben Island
# ...                     ...                             ...
# 6304                    NaN                             NaN
# 6305                    NaN                             NaN
# 6306                    NaN                             NaN
# 6307                    NaN                             NaN
# 6308                    NaN                             NaN
#
#                      Activity  \
# 6209            Spearfishing
# 6210             Wade-fishing
# 6211  Free diving for sponges
# 6212                  Fishing
# 6213                 Swimming
# ...                       ...
# 6304                      NaN
# 6305                      NaN
# 6306                      NaN
# 6307                      NaN
# 6308                      NaN
#
#                                                     Name Sex   Age  \
# 6209                                     4 French divers    M  NaN
# 6210                                           Ed Snyder    M  NaN
# 6211                                                male    M  NaN
# 6212  4.8-metre skiboat, Occupants: Rod Salm & 4 friends  NaN  NaN
# 6213                              male, a mental patient    M  NaN
# ...                                                  ...  ...  ...
# 6304                                                 NaN  NaN  NaN
# 6305                                                 NaN  NaN  NaN
# 6306                                                 NaN  NaN  NaN
# 6307                                                 NaN  NaN  NaN
# 6308                                                 NaN  NaN  NaN
#
#                                             Injury Fatal (Y/N) Time  \
# 6209  FATAL (x3), one survived with minor injuries           Y  NaN
# 6210              No injury, shark rammed his back           N  NaN
# 6211                                         FATAL           Y  NaN
# 6212     No injury to occupants, shark bumped boat           N  NaN
# 6213                     FATAL, body not recovered           Y  NaN
# ...                                            ...         ...  ...
# 6304                                           NaN         NaN  NaN
# 6305                                           NaN         NaN  NaN
# 6306                                           NaN         NaN  NaN
# 6307                                           NaN         NaN  NaN
# 6308                                           NaN         NaN  NaN
#
#                                       Species  \
# 6209  said to involve 2.5 m hammerhead sharks
# 6210                                      NaN
# 6211                                      NaN
# 6212                              Whale shark
# 6213                                      NaN
# ...                                       ...
# 6304                                      NaN
# 6305                                      NaN
# 6306                                      NaN
# 6307                                      NaN
# 6308                                      NaN
#
#                             Investigator or Source  \
# 6209      http://waterco.com.br/ataque_tubarao.htm
# 6210                              Fishingworld.com
# 6211                                  M. Kalafatas
# 6212               South African Shark Attack File
# 6213  L.Green, A Decent Fellow doesn't Work, p.225
# ...                                            ...
# 6304                                           NaN
# 6305                                           NaN
# 6306                                           NaN
# 6307                                           NaN
# 6308                                           NaN
#
#                                pdf  \
# 6209      ND-0110-FrenchDivers.pdf
# 6210         ND-0109-Ed-Snyder.pdf
# 6211  ND-0108-SpongeDiver-Symi.pdf
# 6212         ND-0107-Inhambane.pdf
# 6213     ND-0106-MentalPatient.pdf
# ...                            ...
# 6304                           NaN
# 6305                           NaN
# 6306                           NaN
# 6307                           NaN
# 6308                           NaN
#
#                                                                                     href  \
# 6209      http://sharkattackfile.net/spreadsheets/pdf_directory/ND-0110-FrenchDivers.pdf
# 6210         http://sharkattackfile.net/spreadsheets/pdf_directory/ND-0109-Ed-Snyder.pdf
# 6211  http://sharkattackfile.net/spreadsheets/pdf_directory/ND-0108-SpongeDiver-Symi.pdf
# 6212         http://sharkattackfile.net/spreadsheets/pdf_directory/ND-0107-Inhambane.pdf
# 6213     http://sharkattackfile.net/spreadsheets/pdf_directory/ND-0106-MentalPatient.pdf
# ...                                                                                  ...
# 6304                                                                                 NaN
# 6305                                                                                 NaN
# 6306                                                                                 NaN
# 6307                                                                                 NaN
# 6308                                                                                 NaN
#
#       original order
# 6209            94.0
# 6210            93.0
# 6211            92.0
# 6212            91.0
# 6213            90.0
# ...              ...
# 6304          6306.0
# 6305          6307.0
# 6306          6308.0
# 6307          6309.0
# 6308          6310.0
#
# [100 rows x 19 columns]

# %%
attacks.shape
# Out:
# (6309, 19)

# %% [markdown]
# Our DataFrame dropped from 25.723 rows to just 6.309. However, looking at the tail, it looks like we have rows that are NaNs except for the last column ("Original Order"). We might have columns like this in the middle of the DataFrame as well. Let's drop all rows with more than 14 NaN as they add little value to our analysis.

# %%
attacks.dropna(thresh=14,inplace=True)
attacks.shape
# Out:
# (6167, 19)

# %% [markdown]
# We have now dropped to 6.167 rows! Lets check the DataFrame Info.

# %%
attacks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6167 entries, 0 to 6301
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             6167 non-null   object
#  1   Date                    6167 non-null   object
#  2   Year                    6165 non-null   float64
#  3   Type                    6164 non-null   object
#  4   Country                 6140 non-null   object
#  5   Area                    5791 non-null   object
#  6   Location                5716 non-null   object
#  7   Activity                5709 non-null   object
#  8   Name                    6030 non-null   object
#  9   Sex                     5689 non-null   object
#  10  Age                     3468 non-null   object
#  11  Injury                  6148 non-null   object
#  12  Fatal (Y/N)             5670 non-null   object
#  13  Time                    2946 non-null   object
#  14  Species                 3424 non-null   object
#  15  Investigator or Source  6151 non-null   object
#  16  pdf                     6167 non-null   object
#  17  href                    6167 non-null   object
#  18  original order          6167 non-null   float64
# dtypes: float64(2), object(17)
# memory usage: 963.6+ KB

# %% [markdown]
# Great! We've gotten our Data set to a number 6.167 rows and most of the columns have almost all values completed. Now lets start cleaning the data in each columns, starting with the date information.
#
#
# ## Date information
# It looks like the case number is in fact the date. It might be easier to get the value of date from this column than to extract it from the "Date" column.

# %%
attacks["Case Number"].value_counts()
# Out:
# 1966.12.26      2
# 1907.10.16.R    2
# 2012.09.02.b    2
# 2013.10.05      2
# 1983.06.15      2
#                ..
# 2000.02.19      1
# 2000.02.21      1
# 2000.03.00      1
# 2000.03.02      1
# ND.0001         1
# Name: Case Number, Length: 6151, dtype: int64

# %% [markdown]
# Since most of the data in this column could translate into a date we'll use the "extract_date" function to get a new column with a formatted date using a regex expression.

# %%
extract_date(attacks,"Case Number")
attacks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6167 entries, 0 to 6301
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             6167 non-null   object
#  1   Date                    6167 non-null   object
#  2   Year                    6165 non-null   float64
#  3   Type                    6164 non-null   object
#  4   Country                 6140 non-null   object
#  5   Area                    5791 non-null   object
#  6   Location                5716 non-null   object
#  7   Activity                5709 non-null   object
#  8   Name                    6030 non-null   object
#  9   Sex                     5689 non-null   object
#  10  Age                     3468 non-null   object
#  11  Injury                  6148 non-null   object
#  12  Fatal (Y/N)             5670 non-null   object
#  13  Time                    2946 non-null   object
#  14  Species                 3424 non-null   object
#  15  Investigator or Source  6151 non-null   object
#  16  pdf                     6167 non-null   object
#  17  href                    6167 non-null   object
#  18  original order          6167 non-null   float64
#  19  date_p                  5331 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(17)
# memory usage: 1011.8+ KB

# %% [markdown]
# ## Activity information
# The activities in the DataFrame are quite varied. For this we will use the "extract_activity" function to standarize the data.

# %%
extract_activity(attacks,"Activity")
attacks["activity_p"].value_counts()
# Out:
# swimming    2739
# surfing     1529
# fishing      987
# others       638
# sailing      274
# Name: activity_p, dtype: int64

# %% [markdown]
# We can see that the function reduced the "Others category" to around 10% of the values.
#
# ## Time of day information

# %%
process_time_of_day(attacks,"Time")
print(attacks[["cat_time_of_day"]].value_counts())
print(attacks[["int_time_of_day"]].value_counts())
# Out:
# cat_time_of_day
# afternoon          245
# morning            151
# night               93
# dtype: int64
# int_time_of_day
# 11                 259
# 16                 240
# 15                 237
# 14                 237
# 12                 204
# 13                 200
# 17                 199
# 10                 181
# 18                 131
# 09                 123
# 08                  92
# 07                  83
# 19                  53
# 06                  38
# 20                  30
# 05                  11
# 03                  10
# 23                   8
# 02                   7
# 01                   6
# 04                   6
# 21                   5
# 22                   5
# 00                   1
# dtype: int64

# %%
attacks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6167 entries, 0 to 6301
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             6167 non-null   object
#  1   Date                    6167 non-null   object
#  2   Year                    6165 non-null   float64
#  3   Type                    6164 non-null   object
#  4   Country                 6140 non-null   object
#  5   Area                    5791 non-null   object
#  6   Location                5716 non-null   object
#  7   Activity                5709 non-null   object
#  8   Name                    6030 non-null   object
#  9   Sex                     5689 non-null   object
#  10  Age                     3468 non-null   object
#  11  Injury                  6148 non-null   object
#  12  Fatal (Y/N)             5670 non-null   object
#  13  Time                    2946 non-null   object
#  14  Species                 3424 non-null   object
#  15  Investigator or Source  6151 non-null   object
#  16  pdf                     6167 non-null   object
#  17  href                    6167 non-null   object
#  18  original order          6167 non-null   float64
#  19  date_p                  5331 non-null   datetime64[ns]
#  20  activity_p              6167 non-null   object
#  21  int_time_of_day         2366 non-null   object
#  22  cat_time_of_day         489 non-null    object
# dtypes: datetime64[ns](1), float64(2), object(20)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Age information

# %%
correct_age(attacks,"Age")
attacks[["Age","age_p"]]
# Out:
#       Age age_p
# 0      57    57
# 1      11    11
# 2      48    48
# 3     NaN
# 4     NaN
# ...   ...   ...
# 6297  NaN
# 6298  NaN
# 6299  NaN
# 6300  NaN
# 6301   15    15
#
# [6167 rows x 2 columns]

# %% [markdown]
# ## Fatal attack information

# %%
correct_fatality(attacks,'Fatal (Y/N)')
attacks[["Fatal (Y/N)","fatal_p"]]
attacks.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species', 'Investigator or Source', 'pdf', 'href', 'original order',
#        'date_p', 'activity_p', 'int_time_of_day', 'cat_time_of_day', 'age_p',
#        'fatal_p'],
#       dtype='object')

# %% [markdown]
# ## Species information

# %%
# %run -i 'src/cleaning.py'
process_species(attacks,"Species")
attacks[["Species","species_p"]]
# Out:
#               Species            species_p
# 0         White shark          White Shark
# 1                 NaN  Uncomfirmed Species
# 2                 NaN  Uncomfirmed Species
# 3           2 m shark  Uncomfirmed Species
# 4     Tiger shark, 3m          Tiger Shark
# ...               ...                  ...
# 6297              NaN  Uncomfirmed Species
# 6298              NaN  Uncomfirmed Species
# 6299              NaN  Uncomfirmed Species
# 6300              NaN  Uncomfirmed Species
# 6301              NaN  Uncomfirmed Species
#
# [6167 rows x 2 columns]

# %% [markdown]
# ## Export to CSV

# %%
attacks.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species', 'Investigator or Source', 'pdf', 'href', 'original order',
#        'date_p', 'activity_p', 'int_time_of_day', 'cat_time_of_day', 'age_p',
#        'fatal_p', 'species_p'],
#       dtype='object')

# %%
attacks.to_csv('./data/clean_attacks_full.csv')
delete_columns(attacks,['Date','Type','Activity', 'Name', 'Age', 'Fatal (Y/N)', 'Time', 'Species','Investigator or Source', 'pdf', 'href', 'original order', 'Injury'])
attacks = attacks[['Case Number', 'date_p', 'Year', 'Country', 'Area', 'Location', 'Sex ', 'age_p', 'activity_p', 'int_time_of_day', 'cat_time_of_day', 'fatal_p', 'species_p']]
attacks.rename(columns={'date_p' : 'Date',
                        'age_p' : 'Age',
                        'activity_p' : 'Activity',
                        'int_time_of_day' : 'Time_int',
                        'cat_time_of_day' : 'Time_cat',
                        'fatal_p' : 'Fatal',
                        'species_p' : 'Species'}, inplace=True, errors='raise')
attacks.to_csv('./data/clean_attacks.csv')
# Out:
# Deleted columns:  ['Date', 'Type', 'Activity', 'Name', 'Age', 'Fatal (Y/N)', 'Time', 'Species', 'Investigator or Source', 'pdf', 'href', 'original order', 'Injury']
